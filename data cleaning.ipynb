# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('goalscorers.csv')

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df['Year']= df['date'].dt.year

# %%
df['Month']=df['date'].dt.month

# %%
df['Day']=df['date'].dt.day

# %%
df
# Out:
#             date  home_team away_team       team            scorer  minute  \
# 0     1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    44.0
# 1     1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    55.0
# 2     1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    70.0
# 3     1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    75.0
# 4     1916-07-06  Argentina     Chile  Argentina     Alberto Ohaco     2.0
# ...          ...        ...       ...        ...               ...     ...
# 44357 2024-07-13     Canada   Uruguay    Uruguay       Luis Suárez    90.0
# 44358 2024-07-14  Argentina  Colombia  Argentina  Lautaro Martínez   112.0
# 44359 2024-07-14      Spain   England      Spain     Nico Williams    47.0
# 44360 2024-07-14      Spain   England    England       Cole Palmer    73.0
# 44361 2024-07-14      Spain   England      Spain   Mikel Oyarzabal    86.0
#
#        own_goal  penalty  Year  Month  Day
# ...

# %%
df.isnull().sum()
# Out:
# date           0
# home_team      0
# away_team      0
# team           0
# scorer        49
# minute       259
# own_goal       0
# penalty        0
# Year           0
# Month          0
# Day            0
# dtype: int64

# %%
df
# Out:
#             date  home_team away_team       team            scorer  minute  \
# 0     1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    44.0
# 1     1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    55.0
# 2     1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    70.0
# 3     1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    75.0
# 4     1916-07-06  Argentina     Chile  Argentina     Alberto Ohaco     2.0
# ...          ...        ...       ...        ...               ...     ...
# 44357 2024-07-13     Canada   Uruguay    Uruguay       Luis Suárez    90.0
# 44358 2024-07-14  Argentina  Colombia  Argentina  Lautaro Martínez   112.0
# 44359 2024-07-14      Spain   England      Spain     Nico Williams    47.0
# 44360 2024-07-14      Spain   England    England       Cole Palmer    73.0
# 44361 2024-07-14      Spain   England      Spain   Mikel Oyarzabal    86.0
#
#        own_goal  penalty  Year  Month  Day
# ...

# %%
df.isnull().sum()
# Out:
# date        0
# team        0
# scorer      0
# minute      0
# own_goal    0
# penalty     0
# Year        0
# Month       0
# Day         0
# dtype: int64

# %%
mean = df['minute'].mean()

# %%
df['minute'].fillna(mean)
# Out:
# 0         44.0
# 1         55.0
# 2         70.0
# 3         75.0
# 4          2.0
#          ...
# 44357     90.0
# 44358    112.0
# 44359     47.0
# 44360     73.0
# 44361     86.0
# Name: minute, Length: 44362, dtype: float64

# %%
undefinied = 'undefinied'
df['scorer'].fillna(undefinied)
# Out:
# 0         José Piendibene
# 1        Isabelino Gradín
# 2        Isabelino Gradín
# 3         José Piendibene
# 4           Alberto Ohaco
#                ...
# 44357         Luis Suárez
# 44358    Lautaro Martínez
# 44359       Nico Williams
# 44360         Cole Palmer
# 44361     Mikel Oyarzabal
# Name: scorer, Length: 44362, dtype: object

# %%
df['scorer']= df['scorer'].fillna(undefinied)

# %%
df.isnull().sum()
df
# Out:
#             date       team            scorer  minute  own_goal  penalty  \
# 0     1916-07-02    Uruguay   José Piendibene    44.0     False    False
# 1     1916-07-02    Uruguay  Isabelino Gradín    55.0     False    False
# 2     1916-07-02    Uruguay  Isabelino Gradín    70.0     False    False
# 3     1916-07-02    Uruguay   José Piendibene    75.0     False    False
# 4     1916-07-06  Argentina     Alberto Ohaco     2.0     False    False
# ...          ...        ...               ...     ...       ...      ...
# 44357 2024-07-13    Uruguay       Luis Suárez    90.0     False    False
# 44358 2024-07-14  Argentina  Lautaro Martínez   112.0     False    False
# 44359 2024-07-14      Spain     Nico Williams    47.0     False    False
# 44360 2024-07-14    England       Cole Palmer    73.0     False    False
# 44361 2024-07-14      Spain   Mikel Oyarzabal    86.0     False    False
#
#        Year  Month  Day
# 0      1916      7    2
# 1      1916      7    2
# ...

# %%
df = df.drop(columns=['home_team','away_team'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 df = df.drop(columns=['home_team','away_team'])
#
# File ~\PycharmProjects\pythonProject\venv\lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
df_fixed = df

# %%
df_fixed
# Out:
#             date       team            scorer  minute  own_goal  penalty  \
# 0     1916-07-02    Uruguay   José Piendibene    44.0     False    False
# 1     1916-07-02    Uruguay  Isabelino Gradín    55.0     False    False
# 2     1916-07-02    Uruguay  Isabelino Gradín    70.0     False    False
# 3     1916-07-02    Uruguay   José Piendibene    75.0     False    False
# 4     1916-07-06  Argentina     Alberto Ohaco     2.0     False    False
# ...          ...        ...               ...     ...       ...      ...
# 44357 2024-07-13    Uruguay       Luis Suárez    90.0     False    False
# 44358 2024-07-14  Argentina  Lautaro Martínez   112.0     False    False
# 44359 2024-07-14      Spain     Nico Williams    47.0     False    False
# 44360 2024-07-14    England       Cole Palmer    73.0     False    False
# 44361 2024-07-14      Spain   Mikel Oyarzabal    86.0     False    False
#
#        Year  Month  Day
# 0      1916      7    2
# 1      1916      7    2
# ...

# %%
df_fixed.to_csv('fixed_goal_scorer.csv',index=False)
